# %%
import sys
sys.path.append('/Users/evangeline.bangsil/Desktop/UTD PROJECT/fm-subtype-discovery')

from analysis.clinical_validation import clinical_validator
import numpy as np

cv = clinical_validator('/Users/evangeline.bangsil/Desktop/DATA_clinical/clinical_clean.csv')
dummy_labels = np.array([0]*33 + [1]*33)
results = cv.run_all(dummy_labels, '/Users/evangeline.bangsil/Desktop/UTD PROJECT/fm-subtype-discovery/results')
print(results)
# Out:
# {'age': np.float64(-0.07501051979103217), 'vas_pain': np.float64(0.43435725818131193), 'hamd_total': np.float64(0.4738916991769111), 'hama_total': np.float64(0.3240264998365616), 'tas_total': np.float64(0.5786268422636952), 'tas_dif': np.float64(0.6121272359926129), 'tas_ddf': np.float64(0.26851151318428446), 'tas_eot': np.float64(0.5258526467004531), 'erq_reappraisal': np.float64(-0.18128894892034575), 'erq_suppression': np.float64(0.019859158076583054)}
#           variable   p_value  cohens_d  p_corrected  significant
# 0              age  0.958998 -0.075011     0.958998        False
# 1         vas_pain  0.074783  0.434357     0.172667        False
# 2       hamd_total  0.086334  0.473892     0.172667        False
# 3       hama_total  0.274407  0.324026     0.457345        False
# 4        tas_total  0.060167  0.578627     0.172667        False
# 5          tas_dif  0.080096  0.612127     0.172667        False
# 6          tas_ddf  0.520011  0.268512     0.650014        False
# ...

# %%
from analysis.clinical_validation import clinical_validator
import numpy as np

cv = clinical_validator('/Users/evangeline.bangsil/Desktop/DATA_clinical/clinical_clean.csv')
dummy_labels = np.array([0]*33 + [1]*33)
results = cv.run_all(dummy_labels, '/Users/evangeline.bangsil/Desktop/UTD PROJECT/fm-subtype-discovery/results')
print(results)
# Out:
# {'age': np.float64(-0.07501051979103217), 'vas_pain': np.float64(0.43435725818131193), 'hamd_total': np.float64(0.4738916991769111), 'hama_total': np.float64(0.3240264998365616), 'tas_total': np.float64(0.5786268422636952), 'tas_dif': np.float64(0.6121272359926129), 'tas_ddf': np.float64(0.26851151318428446), 'tas_eot': np.float64(0.5258526467004531), 'erq_reappraisal': np.float64(-0.18128894892034575), 'erq_suppression': np.float64(0.019859158076583054)}
#           variable   p_value  cohens_d  p_corrected  significant
# 0              age  0.958998 -0.075011     0.958998        False
# 1         vas_pain  0.074783  0.434357     0.172667        False
# 2       hamd_total  0.086334  0.473892     0.172667        False
# 3       hama_total  0.274407  0.324026     0.457345        False
# 4        tas_total  0.060167  0.578627     0.172667        False
# 5          tas_dif  0.080096  0.612127     0.172667        False
# 6          tas_ddf  0.520011  0.268512     0.650014        False
# ...
