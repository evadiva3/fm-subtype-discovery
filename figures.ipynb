# %% [markdown]
# #  figures

# %%
# %matplotlib inline
from figures import plot_null_correction, plot_reproducibility, plot_silhouette_vs_participation

# %% [markdown]
# ##the null misspecification and its consequence

# %%
fig1 = plot_null_correction()
fig1

# %% [markdown]
# ## reproducibility across retraining

# %%
fig2 = plot_reproducibility()
fig2

# %% [markdown]
# ## silhouette vs participation ratio

# %%
fig3 = plot_silhouette_vs_participation()
fig3
