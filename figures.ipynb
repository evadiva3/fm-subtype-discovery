# %% [markdown]
# #  figures

# %%
# %matplotlib inline
from figures import plot_pipeline_instability, plot_silhouette_vs_effrank

# %% [markdown]
# ## Figure 1

# %%
fig1 = plot_pipeline_instability()
fig1

# %% [markdown]
# ## Figure 2

# %%
fig2 = plot_silhouette_vs_effrank()
fig2
